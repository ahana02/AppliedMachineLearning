# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (3.1.4)
# Requirement already satisfied: mlflow-skinny==3.1.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: Flask<4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (3.9.4)
# Requirement already satisfied: numpy<3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (20.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (1.3.2)
# Requirement already satisfied: scipy<2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (0.88.0)
# Requirement already satisfied: fastapi<1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (0.120.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlflow-skinny==3.1.4->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (6.30.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlflow-skinny==3.1.4->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mlflow-skinny==3.1.4->mlflow) (0.38.0)
# Requirement already satisfied: Mako in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (2.4.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python39\site-packages (from click<9,>=7.0->mlflow-skinny==3.1.4->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.48.0)
# Requirement already satisfied: pywin32>=304 in c:\users\user\appdata\roaming\python\python39\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.49.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.0.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4->mlflow) (6.5.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.4->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (2025.6.15)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn<2->mlflow) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from uvicorn<1->mlflow-skinny==3.1.4->mlflow) (0.16.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.23)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import mlflow
import mlflow.sklearn

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import average_precision_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

# %%
train_df = pd.read_csv("Data/train.csv")
val_df = pd.read_csv("Data/validation.csv")
test_df = pd.read_csv("Data/test.csv")

X_train, y_train = train_df["text"], train_df["label"]
X_val, y_val = val_df["text"], val_df["label"]
X_test, y_test = test_df["text"], test_df["label"]

# %%
train_df.isna().sum()
# Out:
# label    0
# text     2
# dtype: int64

# %%
def clean_nan_rows(df):
    df = df.dropna(subset=["text"])
    df = df[df["text"].str.strip() != ""]
    return df

# %%
train_df = clean_nan_rows(train_df)
val_df = clean_nan_rows(val_df)
test_df = clean_nan_rows(test_df)

# %%
def vectorize_text(train_texts, val_texts=None, test_texts=None):
    vectorizer = TfidfVectorizer(
        stop_words="english",
        max_features=5000
    )

    X_train = vectorizer.fit_transform(train_texts)
    X_val = vectorizer.transform(val_texts) if val_texts is not None else None
    X_test = vectorizer.transform(test_texts) if test_texts is not None else None

    return vectorizer, X_train, X_val, X_test

# %%
X_train_vec = train_df["text"]
y_train = train_df["label"]

X_val_vec = val_df["text"]
y_val = val_df["label"]

vectorizer, X_train, X_val, _ = vectorize_text(
    X_train_vec,
    X_val_vec
)

# %%
models = {
    "NaiveBayes": MultinomialNB(),
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "LinearSVM": LinearSVC()
}

# %%
mlflow.set_experiment("sms_spam_classification")

results = {}

# %%
for name, model in models.items():

    with mlflow.start_run(run_name=name):

        model.fit(X_train, y_train)

        val_scores = model.decision_function(X_val) if hasattr(model, "decision_function") \
                     else model.predict_proba(X_val)[:, 1]

        aucpr = average_precision_score(y_val, val_scores)

        mlflow.log_param("model", name)
        mlflow.log_metric("AUCPR", aucpr)

        mlflow.sklearn.log_model(
            model,
            name="model",
            input_example=X_train[:5]
        )


        results[name] = aucpr
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
best_model = max(results, key=results.get)
print("Best model:", best_model)

with mlflow.start_run(run_name="best_model"):
    mlflow.log_param("best_model", best_model)
# Out:
# Best model: LinearSVM

# %%
for k, v in results.items():
    print(k, "AUCPR:", v)
# Out:
# NaiveBayes AUCPR: 0.960256916066198
# LogisticRegression AUCPR: 0.9389795687631639
# LinearSVM AUCPR: 0.9645746701525639
